# %%
import pandas as pd
from tabula import read_pdf

# %%
pdf_26 = r"D:\Algoritmo-de-previsao-de-percentual-de-vitorias\historico_nbb\historico_pdf\Tabela_de_jogos_26.pdf"
dfs_26 = read_pdf(pdf_26, pages="all")
df_26 = pd.concat(dfs_26, ignore_index=True)
# Out:
# O Kernel deu pane ao executar o código na célula atual ou em uma célula anterior.
#
# Analise o código nas células para identificar uma possível causa da pane.
#
# Clique <a href='https://aka.ms/vscodeJupyterKernelCrash'>aqui</a> para obter mais informações.
#
# Consulte Jupyter <a href='command:jupyter.viewOutput'>log</a> para obter mais detalhes.

# %%
pdf_25 = r"D:\Algoritmo-de-previsao-de-percentual-de-vitorias\historico_nbb\historico_pdf\Tabela_de_jogos_25.pdf"
dfs_25 = read_pdf(pdf_25, pages="all")
df_25 = pd.concat(dfs_25, ignore_index=True)
# Out:
# Failed to import jpype dependencies. Fallback to subprocess.
# No module named 'jpype'

# %%
pdf_24 = r"D:\Algoritmo-de-previsao-de-percentual-de-vitorias\historico_nbb\historico_pdf\Tabela_de_jogos_24.pdf"
dfs_24 = read_pdf(pdf_24, pages="all")
df_24 = pd.concat(dfs_24, ignore_index=True)

# %%
df_26.head()
# Out:
#                DATA                       CASA                   PLACAR  \
# 0  17/10/2026 16:00  JOGO 1 - 17/10/2026 16:00            Mogi Basquete
# 1  17/10/2026 18:00  JOGO 2 - 17/10/2026 18:00  Caxias do Sul\rBasquete
# 2  17/10/2026 18:30  JOGO 3 - 17/10/2026 18:30                UNIFACISA
# 3  18/10/2026 11:00  JOGO 4 - 18/10/2026 11:00                 Flamengo
# 4  19/10/2026 19:30  JOGO 5 - 19/10/2026 19:30              Sesi Franca
#
#   VISITANTE                RODADA FASE GINÁSIO        Unnamed: 0
# 0         X           Corinthians   1a      1o  Prof. Hugo Ramos
# 1         X              Cruzeiro   1a      1o              Sesi
# 2         X         Basket Osasco   1a      1o   Arena UNIFACISA
# 3         X          Bauru Basket   2a      1o     Maracanãzinho
# 4         X  São José\rBasketball   2a      1o  Ginásio Pedrocão

# %%
lista = ["CASA", "PLACAR", "VISITANTE", "RODADA"]
df_26 = df_26[lista]

# %%
df_26.head(10)

# %%
rename = {
    "CASA": "DATA",
    "PLACAR": "CASA",
    "VISITANTE": "PLACAR",
    "RODADA": "VISITANTE"
}
df_26.columns = df_26.columns.map(lambda x: rename.get(x, x))

df_26.head(10)
